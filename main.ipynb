# %%
#Import libraries
import pandas as pd
import seaborn as sns
import matplotlib as plt
import numpy as np

# %%
dfGT = pd.read_csv("data/GlobalTemperatures.csv") 
dfState = pd.read_csv("data/GlobalLandTemperaturesByState.csv")
dfCountry = pd.read_csv("data/GlobalLandTemperaturesByCountry.csv")
dfMajorCity = pd.read_csv("data/GlobalLandTemperaturesByMajorCity.csv")
dfCity = pd.read_csv("data/GlobalLandTemperaturesByCity.csv")
dfData = pd.read_csv("data/2017_Greenhouse_Gas_Report_Facility_Data.csv")

# %%
dfData
dfGT
dfState
dfCountry
dfMajorCity
dfCity
# Out:
#                                                 Source  \
# 0    King County Solid Waste Cedar Hills Landfill -...
# 1                 The Boeing Company: DC/MFC - Tukwila
# 2             Phillips 66 Ferndale Refinery - Ferndale
# 3    Agrium Kennewick Fertilizer Operations (KFO) -...
# 4                    Northwest Pipeline C/S - Chehalis
# 5              River Road Generating Plant - Vancouver
# 6                          Ardagh Glass Inc. - Seattle
# 7                     SGL Composites  LLC - Moses Lake
# 8            Bio Energy Washington, LLC - Maple Valley
# 9    Hampton Lumber Mills Washington Inc. - Darrington
# 10                    U.S. Oil & Refining Co. - Tacoma
# 11                      Frederickson Power LP - Tacoma
# 12                            Cheyne Landfill - Zillah
# 13             El Oro Cattle Feeders, LLC - Moses Lake
# 14        City of Tacoma Solid Waste Facility - Tacoma
# 15                   Grays Harbor Energy Center - Elma
# ...
